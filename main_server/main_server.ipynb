# %%
#Final_Server의 main_server

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Final_Server/main_server
# Out:
# /content/drive/MyDrive/Final_Server/main_server

# %%
# !pip install flask flask-cors pyngrok requests

# %%
# !python main_server.py
# Out:
# ✅ REVIEW_SERVER_URL: https://84c4-34-13-245-17.ngrok-free.app
# ✅ FAST3R_SERVER_URL: https://faa7-34-72-176-63.ngrok-free.app
# ✅ TWOD_SERVER_URL: https://bd68-35-240-214-92.ngrok-free.app
# 💡 ngrok 연결 완료
# 💡 Main 서버 ngrok 외부 URL: https://d677-34-169-56-80.ngrok-free.app
#  * Serving Flask app 'main_server'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:5000
#  * Running on http://172.28.0.12:5000
# Press CTRL+C to quit
# 127.0.0.1 - - [10/Jun/2025 18:37:17] "OPTIONS /3d_upload HTTP/1.1" 200 -
# ...
